# %% [markdown]
# # Customer Retention Case Study

# %% [markdown]
# ## Introduction

# %% [markdown]
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Today, with the increasing recognition of the importance of customer retention and loyalty, companies now understand the importance of service.
# The idea is that to understand the needs of customers as well as the changes in their needs over the time.
# If the companies want loyal customers, the customers must be  satisfied.  The  company should know what customers want from them. Companies must provide good services to attract more and more customers. Ways to achieve combination of both utilitarian value and hedonistic values for repeat purchase intention.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd # for handling dataset
import numpy as np  # for mathematical computation

# for visualization
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# reading the data
df=pd.read_excel(r'D:\DATATRAINED\Internship-FlipnRobo\Projects\Customer_retention_dataset\customer_retention_dataset.xlsx')

# %%
df.head() # to display top 5 rows from dataset
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
print('Total no of rows & columns: ',df.shape) # to check number of rows & columns
# Out:
# Total no of rows & columns:  (269, 71)

# %%
print('List of columns: ',df.columns) # to display all the columns name in the dataset
# Out:
# List of columns:  Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
# ...

# %%
df.isnull().sum()  # to check null values
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# #### No null values in the dataset

# %%
df.info() # to know datatype of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# to count number of unique values in each columns 
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
df.describe().T # to get high understanding of dataset or to get overview/stats of the dataset
# Out:
#                                                     count           mean  \
# 4 What is the Pin Code of where you shop online...  269.0  220465.747212
#
#                                                               std       min  \
# 4 What is the Pin Code of where you shop online...  140524.341051  110008.0
#
#                                                          25%       50%  \
# 4 What is the Pin Code of where you shop online...  122018.0  201303.0
#
#                                                          75%       max
# 4 What is the Pin Code of where you shop online...  201310.0  560037.0

# %%
# renaming the columns from column1-column17
df = df.rename(columns={'1Gender of respondent': 'Gender', '2 How old are you? ': 'Age range',
        '3 Which city do you shop online from?':'City','4 What is the Pin Code of where you shop online from?':'Pincode',
     '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ': 
    'Mobile screen size',
    '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':
    'Operating system',
    '11 What browser do you run on your device to access the website?\t\t\t                                                          ':
    'Browser',
    '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':
    'Channel followed to arrive 1st time to online store',
    '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ': 'After first visit, how do you reach the online retail store',
    '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':
    'How much time do you explore the e- retail store before making a purchase decision?',
    '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ': 
                        'Preferred payment option',
    '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':
    'How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart',
    '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':
    'Why did you abandon the “Bag”, “Shopping Cart”',
    'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':
    'online retailers you have shopped from',
    '8 Which device do you use to access the online shopping?': 'Device',
    'What is your preferred payment Option?':'Payment Option','7 How do you access the internet while shopping on-line?':'Internet access',
     '5 Since How Long You are Shopping Online ?':'Years of Online Shopping','6 How many times you have made an online purchase in the past 1 year?':
        'Online purchase in past 1 year','After first visit, how do you reach the online retail store':'After 1st visit,how do you reach the online retail store',
     'How much time do you explore the e- retail store before making a purchase decision?':'Time taken to explore the e- retail store before making a purchase decision?'})

# %%
# to count number of unique values 
df['Online purchase in past 1 year'].unique()
# Out:
# array(['31-40 times', '41 times & above', 'Less than 10 times',
#        '11-20 times', '21-30 times'], dtype=object)

# %% [markdown]
# #### In above column , '41 times and above' and '42 times and above' represent same thing

# %%
# removing duplicate and appending into one
df['Online purchase in past 1 year']=df['Online purchase in past 1 year'].replace(
                                     ['41 times and above','42 times and above'],'41 times & above',regex=True)

# %%
# renaming elements in Age range list
df['Age range']=df['Age range'].replace('Less than 20 years','<20 years',regex=True)
df['Age range']=df['Age range'].replace('41-50 yaers','41-50 years',regex=True)
df['Age range']=df['Age range'].replace('51 years and above','>=51 years',regex=True)

# %%
# to count number of unique values 
df['Internet access'].unique()
# Out:
# array(['Dial-up', 'Wi-Fi', 'Mobile Internet', 'Mobile internet'],
#       dtype=object)

# %% [markdown]
# #### Same element (Mobile Internet) present twice

# %%
# appending duplicate values into one
df['Internet access']=df['Internet access'].replace('Mobile internet','Mobile Internet',regex=True)

# %% [markdown]
# ## Univariate Analysis

# %%
fig,ax = plt.subplots(6,2,figsize=(14,12))
sns.countplot('Gender',data=df,ax=ax[0][0])
sns.countplot('Age range',data=df,ax=ax[0][1])
sns.countplot('Internet access',data=df,ax=ax[1][0])
sns.countplot('Device',data=df,ax=ax[1][1])
sns.countplot('Operating system',data=df,ax=ax[2][0])
sns.countplot('Browser',data=df,ax=ax[2][1])
sns.countplot('Channel followed to arrive 1st time to online store',data=df,ax=ax[3][0])
sns.countplot('Preferred payment option',data=df,ax=ax[3][1])
sns.countplot('Online purchase in past 1 year',data=df,ax=ax[4][0])
sns.countplot('Years of Online Shopping',data=df,ax=ax[4][1])
sns.countplot('After 1st visit,how do you reach the online retail store',data=df,ax=ax[5][0])
sns.countplot('Time taken to explore the e- retail store before making a purchase decision?',data=df,ax=ax[5][1])

plt.tight_layout()

# %% [markdown]
# #### Inferences from above plot
#
# 1. Female respondents is double in number than male respondents in giving survey.
# 2. Lots of respondents age ranges from(31-50 years)
# 3. Mobile Internet is widely used for shopping online.
# 4. Use of smartphone for online shopping is done most than other gadgets.
# 5. Operating system that they use most in their device is Window/windows Mobile.
# 6. Google Chrome browser is mostly used for online shopping.
# 7. To browse online store,Search Engine is used most.
# 8. Credit/Debit cards is used mostly for payment for online shopping.
# 9. In a year , maximum online purchases have been done less than 10 times.
# 10. Maximum number of respondents have told that they have been shopping online for more than 4 years.
# 11. Search Engine and Via application is preferred by customers to reach the online retail store after first visit.
# 12. Before making a decision to purchase, customers spending more than 15 minutes is high in count than others.

# %%
# Lets visualize the City column
plt.subplots(figsize=(12,4))
sns.countplot(df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# #### Customers shopping online from the city-Delhi is more in numbers than other cities.

# %%
# lets visualize the Pin Code of where the customers used to shop online from
plt.subplots(figsize=(22,4))
sns.countplot(df['Pincode'])
plt.tight_layout()

# %% [markdown]
# #### Pincode (201308)- GAUTAM BUDDHA NAGAR in state of Uttar Pradesh from where customers do online shopping a lot.

# %%
sns.countplot(df['Mobile screen size'])
# Out:
# <AxesSubplot:xlabel='Mobile screen size', ylabel='count'>

# %%
# dropping coluumn 'Mobile screen size' as its not useful(redundant) for prediction
df=df.drop(columns='Mobile screen size')

# %%
sns.countplot(df['How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart'])
# Out:
# <AxesSubplot:xlabel='How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart', ylabel='count'>

# %% [markdown]
# #### It happens sometimes only when customers abandon shopping cart according to the stats shown above.

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df['Why did you abandon the “Bag”, “Shopping Cart”'])
# Out:
# <AxesSubplot:xlabel='Why did you abandon the “Bag”, “Shopping Cart”', ylabel='count'>

# %% [markdown]
# #### The reason for abandon the bag,shopping cart is that they got better alternative offer.

# %%
# Renaming columns from (column 18-column 45)
df = df.rename(columns={'18 The content on the website must be easy to read and understand':'Content on the website must be easy to read and understandable',
     '19 Information on similar product to the one highlighted  is important for product comparison':'Highlighted information is important for product comparison',
     '20 Complete information on listed seller and product being offered is important for purchase decision.':'Complete Information of seller and product',
     '21 All relevant information on listed products must be stated clearly':'All relevant information on listed products must be stated clearly',
     '22 Ease of navigation in website':'Ease of navigation in website','23 Loading and processing speed':'Loading and processing speed',
    '24 User friendly Interface of the website':'User friendly Interface of the website','25 Convenient Payment methods':'Convenient Payment methods',
    '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust with the online retail store for transaction',
    '27 Empathy (readiness to assist with queries) towards the customers':'Empathy towards the customers',
    '28 Being able to guarantee the privacy of the customer':'Guarantee the privacy of the customer',
     '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Responsiveness',
    '30 Online shopping gives monetary benefit and discounts':'Online shopping gives monetary benefit and discounts',
    '31 Enjoyment is derived from shopping online':'Enjoyment in shopping online','32 Shopping online is convenient and flexible':'Shopping online is convenient and flexible',
    '33 Return and replacement policy of the e-tailer is important for purchase decision':'Return and Replacement policy',
    '34 Gaining access to loyalty programs is a benefit of shopping online':'Loyalty program access from shopping online',
    '35 Displaying quality Information on the website improves satisfaction of customers':'Displaying quality information on the website',
    '36 User derive satisfaction while shopping on a good quality website or application':'Satisfaction while shopping on a good quality website or application',
    '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net benefit from shopping online',
    '38 User satisfaction cannot exist without trust':'User satisfaction cannot exist without trust',
    '39 Offering a wide variety of listed product in several category':'Several category of listed products offered',
    '40 Provision of complete and relevant product information':'Provision of complete and relevant product information',
    '41 Monetary savings':'Monetary savings','42 The Convenience of patronizing the online retailer':'Convenience of patronizing the online retailer',
    '43 Shopping on the website gives you the sense of adventure':'Sense of adventure in online shopping',
     '44 Shopping on your preferred e-tailer enhances your social status':'Enhancement of social status',
    '45 You feel gratification shopping on your favorite e-tailer':'Gratification feeling','46 Shopping on the website helps you fulfill certain roles':
    'Shopping on the website helps you fulfill certain roles','47 Getting value for money spent':'Getting value for money spent'})

# %%
# appending duplicate elements in lists into one (i.e Strongly agree to Agree / Strongly disagree to dis-agree)
df['Content on the website must be easy to read and understandable']=df['Content on the website must be easy to read and understandable'].replace('Strongly agree (5)','Agree (4)')
df['Content on the website must be easy to read and understandable']=df['Content on the website must be easy to read and understandable'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Highlighted information is important for product comparison']=df['Highlighted information is important for product comparison'].replace('Strongly agree (5)','Agree (4)')

df['Complete Information of seller and product']=df['Complete Information of seller and product'].replace('Strongly agree (5)','Agree (4)')
df['Complete Information of seller and product']=df['Complete Information of seller and product'].replace('Strongly disagree (1)','Dis-agree (2)')

df['All relevant information on listed products must be stated clearly']=df['All relevant information on listed products must be stated clearly'].replace('Strongly agree (5)','Agree (4)')
df['All relevant information on listed products must be stated clearly']=df['All relevant information on listed products must be stated clearly'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Ease of navigation in website']=df['Ease of navigation in website'].replace('Strongly agree (5)','Agree (4)')
df['Ease of navigation in website']=df['Ease of navigation in website'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Loading and processing speed']=df['Loading and processing speed'].replace('Strongly agree (5)','Agree (4)')
df['Loading and processing speed']=df['Loading and processing speed'].replace('Strongly disagree (1)','Dis-agree (2)')

df['User friendly Interface of the website']=df['User friendly Interface of the website'].replace('Strongly agree (5)','Agree (4)')
df['User friendly Interface of the website']=df['User friendly Interface of the website'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Convenient Payment methods']=df['Convenient Payment methods'].replace('Strongly agree (5)','Agree (4)')

df['Trust with the online retail store for transaction']=df['Trust with the online retail store for transaction'].replace('Strongly agree (5)','Agree (4)')

df['Empathy towards the customers']=df['Empathy towards the customers'].replace('Strongly agree (5)','Agree (4)')
df['Empathy towards the customers']=df['Empathy towards the customers'].replace('Strongly disagree (1)','Dis-agree (2)')

# %%
fig,ax = plt.subplots(5,2,figsize=(14,12))

sns.countplot('Content on the website must be easy to read and understandable',data=df,ax=ax[0][0])
sns.countplot('Highlighted information is important for product comparison',data=df,ax=ax[0][1])
sns.countplot('Complete Information of seller and product',data=df,ax=ax[1][0])
sns.countplot('All relevant information on listed products must be stated clearly',data=df,ax=ax[1][1])
sns.countplot('Ease of navigation in website',data=df,ax=ax[2][0])
sns.countplot('Loading and processing speed',data=df,ax=ax[2][1])
sns.countplot('User friendly Interface of the website',data=df,ax=ax[3][0])
sns.countplot('Convenient Payment methods',data=df,ax=ax[3][1])
sns.countplot('Trust with the online retail store for transaction',data=df,ax=ax[4][0])
sns.countplot('Empathy towards the customers',data=df,ax=ax[4][1])

plt.tight_layout()

# %% [markdown]
# #### Inferences from above plot
#
# Reports of the survey conducted , answered by respondents.
#
# 1. 90% customers agrees that the content on the website should be easy and understandable.
# 2. 77% customers thinks that the highlighted information is important for product information.
# 3. Approx 70% customers thinks that complete information of seller and product is important for purchase decision.
# 4. 88% customers wants that all relevant information on listed products must be stated clearly.
# 5. 91% customers wants to find the content they are looking for much faster(ease of navigation of a website).
# 6. 84% customers agrees that loading and processing speed of website/application should be quick.
# 7. 87% customers wants a clear visual hierarchy to know where they are on the site(User-friendly Interface of a website)
# 8. 88% customers agrees that there are different modes of payment availability for shopping online.
# 9. 84% customers has shown trust that the online retail store will fulfill its part of the transaction at the stipulated time.
# 10. 88% customers believes that these e-retail online stores show empathy(help them with the queries) towards their customers.

# %%
# appending duplicate elements in lists into one (i.e Strongly agree to Agree / Strongly disagree to dis-agree)
df['Guarantee the privacy of the customer']=df['Guarantee the privacy of the customer'].replace('Strongly agree (5)','Agree (4)')

df['Responsiveness']=df['Responsiveness'].replace('Strongly agree (5)','Agree (4)')
df['Responsiveness']=df['Responsiveness'].replace('Strongly disagree (1)','Disagree')

df['Online shopping gives monetary benefit and discounts']=df['Online shopping gives monetary benefit and discounts'].replace('Strongly agree (5)','Agree (4)')
df['Online shopping gives monetary benefit and discounts']=df['Online shopping gives monetary benefit and discounts'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Enjoyment in shopping online']=df['Enjoyment in shopping online'].replace('Strongly agree (5)','Agree (4)')
df['Enjoyment in shopping online']=df['Enjoyment in shopping online'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Shopping online is convenient and flexible']=df['Shopping online is convenient and flexible'].replace('Strongly agree (5)','Agree (4)')

df['Return and Replacement policy']=df['Return and Replacement policy'].replace('Strongly agree (5)','Agree (4)')

df['Loyalty program access from shopping online']=df['Loyalty program access from shopping online'].replace('Strongly agree (5)','Agree (4)')
df['Loyalty program access from shopping online']=df['Loyalty program access from shopping online'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Displaying quality information on the website']=df['Displaying quality information on the website'].replace('Strongly agree (5)','Agree (4)')

df['Satisfaction while shopping on a good quality website or application']=df['Satisfaction while shopping on a good quality website or application'].replace('Strongly agree (5)','Agree (4)')

df['Net benefit from shopping online']=df['Net benefit from shopping online'].replace('Strongly agree (5)','Agree (4)')

# %%
fig,ax = plt.subplots(5,2,figsize=(14,12))

sns.countplot('Guarantee the privacy of the customer',data=df,ax=ax[0][0])
sns.countplot('Responsiveness',data=df,ax=ax[0][1])
sns.countplot('Online shopping gives monetary benefit and discounts',data=df,ax=ax[1][0])
sns.countplot('Enjoyment in shopping online',data=df,ax=ax[1][1])
sns.countplot('Shopping online is convenient and flexible',data=df,ax=ax[2][0])
sns.countplot('Return and Replacement policy',data=df,ax=ax[2][1])
sns.countplot('Loyalty program access from shopping online',data=df,ax=ax[3][0])
sns.countplot('Displaying quality information on the website',data=df,ax=ax[3][1])
sns.countplot('Satisfaction while shopping on a good quality website or application',data=df,ax=ax[4][0])
sns.countplot('Net benefit from shopping online',data=df,ax=ax[4][1])

plt.tight_layout()

# %% [markdown]
# #### Inferences from above plot
#
# Reports of the survey conducted , answered by respondents.
#
# 1. 90% customers have faith on e-commerce companies of not leaking out their privacy.
# 2. 90% customers thinks that there are availability of several communication channels(email,twitter,phone etc.)
# 3. 70% customers assume that online shopping gives monetary benefits and discounts.
# 4. Only 54% customers enjoy online shopping,rest dis-agree or show no concern.
# 5. 83% customers find online shopping to be convenient and flexible.
# 6. 92% customers wants to know the return and replacement policy of electronic goods before purchasing.
# 7. 66% customers thinks that online shopping will benefit them in gaining access to loyalty programs.
# 8. Approx 80% customers thinks that displaying quality information on the website improves satisfaction of customers.
# 9. Almost all customers agrees that user derive satisfaction when shopping from a good website/application.
# 10. 81% customers agrees that if benefits are provided from online shopping then this leads to user satisfaction.

# %%
# appending duplicate elements in lists into one (i.e Strongly agree to Agree / Strongly disagree to dis-agree)
df['User satisfaction cannot exist without trust']=df['User satisfaction cannot exist without trust'].replace('Strongly agree (5)','Agree (4)')
df['User satisfaction cannot exist without trust']=df['User satisfaction cannot exist without trust'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Several category of listed products offered']=df['Several category of listed products offered'].replace('Strongly agree (5)','Agree (4)')

df['Provision of complete and relevant product information']=df['Provision of complete and relevant product information'].replace('Strongly agree (5)','Agree (4)')

df['Monetary savings']=df['Monetary savings'].replace('Strongly agree (5)','Agree (4)')

df['Convenience of patronizing the online retailer']=df['Convenience of patronizing the online retailer'].replace('Strongly agree (5)','Agree (4)')

df['Sense of adventure in online shopping']=df['Sense of adventure in online shopping'].replace('Strongly agree (5)','Agree (4)')
df['Sense of adventure in online shopping']=df['Sense of adventure in online shopping'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Enhancement of social status']=df['Enhancement of social status'].replace('Strongly agree (5)','Agree (4)')
df['Enhancement of social status']=df['Enhancement of social status'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Gratification feeling']=df['Gratification feeling'].replace('Strongly agree (5)','Agree (4)')
df['Gratification feeling']=df['Gratification feeling'].replace('Strongly disagree (1)','Dis-agree (2)')
df['Gratification feeling']=df['Gratification feeling'].replace('Disagree (2)','Dis-agree (2)')

df['Shopping on the website helps you fulfill certain roles']=df['Shopping on the website helps you fulfill certain roles'].replace('Strongly agree (5)','Agree (4)')
df['Shopping on the website helps you fulfill certain roles']=df['Shopping on the website helps you fulfill certain roles'].replace('Strongly disagree (1)','Dis-agree (2)')

df['Getting value for money spent']=df['Getting value for money spent'].replace('Strongly agree (5)','Agree (4)')

# %%
fig,ax = plt.subplots(5,2,figsize=(14,12))

sns.countplot('User satisfaction cannot exist without trust',data=df,ax=ax[0][0])
sns.countplot('Several category of listed products offered',data=df,ax=ax[0][1])
sns.countplot('Provision of complete and relevant product information',data=df,ax=ax[1][0])
sns.countplot('Monetary savings',data=df,ax=ax[1][1])
sns.countplot('Convenience of patronizing the online retailer',data=df,ax=ax[2][0])
sns.countplot('Sense of adventure in online shopping',data=df,ax=ax[2][1])
sns.countplot('Enhancement of social status',data=df,ax=ax[3][0])
sns.countplot('Gratification feeling',data=df,ax=ax[3][1])
sns.countplot('Shopping on the website helps you fulfill certain roles',data=df,ax=ax[4][0])
sns.countplot('Getting value for money spent',data=df,ax=ax[4][1])

plt.tight_layout()

# %% [markdown]
# #### Inferences from above plot
#
# Reports of the survey conducted , answered by respondents.
#
# 1. Approx 89% customers thinks that trust plays a major role in user satisfaction.
# 2. 76% customers agrees that online retail store offers wide variety of listed product in several category.
# 3. 86% customers agrees that online retail store provides provision of complete and relevant product information.
# 4. 83% customers believes in monetary savings.
# 5. 71% customers have thoughts of being betrayed by the online retailer through online shopping.
# 6. 57% customers agrees that shopping on the website gives them some sense of adventure.
# 7. 37% customers shows no concern and 23% disagrees that shopping on your preferred e-tailer enhances social status.
# 8. Approx 47% customers feels the pleasure of shopping on their favourite e-tailer.
# 9. Mixed thought of customers on shopping on the website helps fulfill certain roles.
# 10. 86% customers believes that they get value for money spent.

# %%
df.groupby('online retailers you have shopped from')['online retailers you have shopped from'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### From the above graph its clear that the customers have shopped from all the retailers(Amazon,Flipkart,Paytm,Myntra,Snapdeal).

# %%
df.groupby('Easy to use website or application')['Easy to use website or application'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Except paytm, customers have find all the e-retailer websites/applications shown above easy to use.

# %%
df.groupby('Visual appealing web-page layout')['Visual appealing web-page layout'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon and Flipkart has surpassed everyone in terms of visual web page layout.

# %%
df.groupby('Wild variety of product on offer')['Wild variety of product on offer'].count().plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('wide variety of products on offer')
plt.show()

# %% [markdown]
# #### Amazon and Flipkart provides maximum wide variety of products on offer than others.

# %%
df.groupby('Complete, relevant description information of products')['Complete, relevant description information of products'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Both Amazon and Flipkart provides complete description information of products then others.

# %%
df.groupby('Fast loading website speed of website and application')['Fast loading website speed of website and application'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon alone has been voted most for fast loading website/application.

# %%
df.groupby('Reliability of the website or application')['Reliability of the website or application'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon is the most reliable website/application.

# %%
df.groupby('Quickness to complete purchase')['Quickness to complete purchase'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### E-commerce company that provides hassle free complete purchase is Amazon as stated by respondents/custoomers.

# %%
df.groupby('Availability of several payment options')['Availability of several payment options'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon and Flipkart provides most several options of payment than others.

# %%
df.groupby('Speedy order delivery ')['Speedy order delivery '].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon & Flipkart both provides speedy order delivery to customers than others.

# %%
df.groupby('Privacy of customers’ information')['Privacy of customers’ information'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon tops the chart in giving privacy to its customers.

# %%
df.groupby('Security of customer financial information')['Security of customer financial information'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### For security purpose, customers have choosen Amazon over others that protects customer financial information.

# %%
df.groupby('Perceived Trustworthiness')['Perceived Trustworthiness'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon has topped the charts in terms of trust with its customers than others.

# %%
df.groupby('Presence of online assistance through multi-channel')['Presence of online assistance through multi-channel'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Customers thinks that amazon provides online support assistance through multi-channel maximum than other e-retail companies.

# %%
df.groupby('Longer time to get logged in (promotion, sales period)')['Longer time to get logged in (promotion, sales period)'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon takes longer user login in time than others as shown in above plot.

# %%
df.groupby('Longer time in displaying graphics and photos (promotion, sales period)')['Longer time in displaying graphics and photos (promotion, sales period)'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon and Flipkart takes longer time than others in displaying graphics and photos as per survey.

# %%
df.groupby('Late declaration of price (promotion, sales period)')['Late declaration of price (promotion, sales period)'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Customers have picked Myntra for most late declaration of price than other e-retail companies.

# %%
df.groupby('Longer page loading time (promotion, sales period)')['Longer page loading time (promotion, sales period)'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Myntra and Paytm takes longer time in page loading.

# %%
df.groupby('Limited mode of payment on most products (promotion, sales period)')['Limited mode of payment on most products (promotion, sales period)'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Snapdeal has been voted most for providing limited mode of payment on most products.

# %%
df.groupby('Longer delivery period')['Longer delivery period'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Paytm and Snapdeal takes longer period than other in delivering goods.

# %%
df.groupby('Change in website/Application design')['Change in website/Application design'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Amazon has the highest count for having change in its website/application design.

# %%
df.groupby('Website is as efficient as before')['Website is as efficient as before'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Customers have voted Amazon more than other e-retailer companies for its website efficiency.

# %%
df.groupby('Which of the Indian online retailer would you recommend to a friend?')['Which of the Indian online retailer would you recommend to a friend?'].count().plot(kind='barh')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# #### Most of them has considered Amazon and Flipkart to be recommended to their friends.

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Gender", hue="Age range", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Popularity of online shopping is more with female customers between age group (21-30 years) as stats show that they have given survey most.

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Age range", hue="Internet access", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Age range', ylabel='Count'>

# %% [markdown]
# #### From (31-50 years) age group people use mostly mobile internet for online shopping. For children (<20 years) and seniors(>=51 years) uses wifi and mobile internet almost both equally for shopping online.

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Device", hue="Internet access", data=df, stat="count", multiple="dodge")
# Out:
# <AxesSubplot:xlabel='Device', ylabel='Count'>

# %% [markdown]
# #### If a user is using smartphone then mostly user will use mobile internet for online shopping and if using laptop then both wifi and mobile internet is used.

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Years of Online Shopping", hue="Gender", data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='Years of Online Shopping', ylabel='Count'>

# %% [markdown]
# #### Female customers have done online shopping more than male.

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Time taken to explore the e- retail store before making a purchase decision?", hue="Gender", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Time taken to explore the e- retail store before making a purchase decision?', ylabel='Count'>

# %% [markdown]
# #### Female customers takes more time exploring e-retail store than male before purchasing anything online.

# %%
plt.subplots(figsize=(10,4))
sns.histplot(binwidth=0.5, x="Operating system", hue="Browser", data=df, stat="count", multiple="fill")
# Out:
# <AxesSubplot:xlabel='Operating system', ylabel='Count'>

# %% [markdown]
# #### Lots of customers using different operating system use google chrome most for online shopping, except customers using iOS/Mac they use safari browser mostly.

# %%
plt.subplots(figsize=(12,5))
sns.histplot(binwidth=0.5, x="Device", hue="Preferred payment option", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Device', ylabel='Count'>

# %% [markdown]
# ####
# 1. If online shopping is done through smartphone, then user prefers cash on delivery (CoD) and Credit/Debit card payment mostly.
#
# 2. If online shopping is done through laptop & tablet, then user prefers Credit/Debit card payment option mostly.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# converting objects into integers
lab_enc = LabelEncoder()
list1 = ['Gender', 'Age range', 'City', 'Pincode', 'Years of Online Shopping',
       'Online purchase in past 1 year', 'Internet access', 'Device',
       'Operating system', 'Browser',
       'Channel followed to arrive 1st time to online store',
       'After 1st visit,how do you reach the online retail store',
       'Time taken to explore the e- retail store before making a purchase decision?',
       'Preferred payment option',
       'How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart',
       'Why did you abandon the “Bag”, “Shopping Cart”',
       'Content on the website must be easy to read and understandable',
       'Highlighted information is important for product comparison',
       'Complete Information of seller and product',
       'All relevant information on listed products must be stated clearly',
       'Ease of navigation in website', 'Loading and processing speed',
       'User friendly Interface of the website', 'Convenient Payment methods',
       'Trust with the online retail store for transaction',
       'Empathy towards the customers',
       'Guarantee the privacy of the customer', 'Responsiveness',
       'Online shopping gives monetary benefit and discounts',
       'Enjoyment in shopping online',
       'Shopping online is convenient and flexible',
       'Return and Replacement policy',
       'Loyalty program access from shopping online',
       'Displaying quality information on the website',
       'Satisfaction while shopping on a good quality website or application',
       'Net benefit from shopping online',
       'User satisfaction cannot exist without trust',
       'Several category of listed products offered',
       'Provision of complete and relevant product information',
       'Monetary savings', 'Convenience of patronizing the online retailer',
       'Sense of adventure in online shopping', 'Enhancement of social status',
       'Gratification feeling',
       'Shopping on the website helps you fulfill certain roles',
       'Getting value for money spent',
       'online retailers you have shopped from',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']
for val in list1:
    df[val] = lab_enc.fit_transform(df[val].astype(str))

# %%
# to check & display top 5 rows from data if all converted into machine language/integers
df.head()
# Out:
#    Gender  Age range  City  Pincode  Years of Online Shopping  \
# 0       1          1     2        1                         3
# 1       0          0     2        5                         3
# 2       0          0     4       23                         2
# 3       1          0     6       11                         2
# 4       0          0     0       31                         1
#
#    Online purchase in past 1 year  Internet access  Device  Operating system  \
# 0                               2                0       0                 2
# 1                               3                2       2                 1
# 2                               3                1       2                 0
# 3                               4                1       2                 1
# 4                               0                2       2                 1
#
#    Browser  ...  Longer time to get logged in (promotion, sales period)  \
# ...

# %%
from scipy.stats import skew

# %%
# to see skewness for each column 
for col in df:
    print(col)
    print(skew(df[col]))
# Out:
# Gender
# 0.736889426659149
# Age range
# 0.6656499283018178
# City
# 0.3119765995524991
# Pincode
# 0.11389691399412398
# Years of Online Shopping
# -0.2754208072611491
# Online purchase in past 1 year
# -0.8441552603034858
# Internet access
# 0.6265344190748209
# Device
# -0.482470142229348
# Operating system
# -0.26877308469479777
# Browser
# 1.700692017835774
# Channel followed to arrive 1st time to online store
# -2.4556928732181134
# After 1st visit,how do you reach the online retail store
# -0.04093111519819523
# Time taken to explore the e- retail store before making a purchase decision?
# -0.38850895683441194
# Preferred payment option
# 0.12901068981369967
# How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart
# -0.8626048441305508
# Why did you abandon the “Bag”, “Shopping Cart”
# 0.7389019460451455
# Content on the website must be easy to read and understandable
# 3.5001557687002736
# ...

# %%
# plotting heatmap to observe the correlation
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, vmin=-1.0, vmax=1.0)
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# 1. Product value is the primary driver for customer retention.
#
# 2. Strong brand-customer relationships drives loyalty and repeat purchases.
#
# 3. If you want to create an effective customer retention strategy, it starts with understanding what your customers value and providing a product that matches that.
#
# 4. Use data to understand your customers, their likes and dislikes, their shopping behavior patterns, etc and customize your services accordingly.
#
# 5. The recipe for customer retention is simple – retail has to become relentlessly customer-focused.
